# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Кирилл :) Спасибо за работу
#
# Стоит поправить вывод результатов стат теста
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, <b>интерпретации значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формировании рекомендаций для бизнеса
#
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил бонус

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Кирилл :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии связаны с неточностями:
#
#
#  + самое важное — переопределить актуальный период
#  + перестроить графики в ТОП-5 (на актуальном периоде)
#  + в разделе проверки гипотез подправить выборки, выводы
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Кирилл :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Сборный проект. Аналитика и прогноз игровой индустрии на 2017г.

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту (со смыслом)

# %% [markdown]
# ## 1. Оглавление

# %% [markdown]
# - [Шаг 1. Откройте файл с данными и изучите общую информацию](#2)
# - [Шаг 2. Подготовьте данные](#3)
# - [Шаг 3. Проведите исследовательский анализ данных](#4)
# - [Шаг 4. Составьте портрет пользователя каждого региона](#5)
# - [Шаг 5. Проверьте гипотезы](#6)
# - [Шаг 6. Напишите общий вывод](#7)
# - [Описание данных](#8)
# - [Вывод](#9)

# %% [markdown]
# ## 2. Описание проекта

# %% [markdown]
# - Иинтернет-магазина «Стримчик», продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# - Исходные данные - Данные до 2016 года включительно. Необхдимо спланирвать кампанию на 2017-й. Нужно отработать принцип работы с данными.
# - В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# ## 3. Постановка задачи

# %% [markdown]
# ### По данным 2016 года, спланировать кампанию на 2017 год:
# - Выявить факторы определяющие успешность игр и закономерности.
# - Выделить потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /Users/macbookair/Yandex.Disk.localized/Проекты_юпитер/games.csv
#
# ### Шаг 2. Подготовьте данные
# - []Замените названия столбцов (приведите к нижнему регистру);
# - []Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
#   - []Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#   - []Опишите причины, которые могли привести к пропускам;
#   - []Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# - []Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# ### Шаг 3. Проведите исследовательский анализ данных
# - []Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - []Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - []Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - []Не учитывайте в работе данные за предыдущие годы.
# - []Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - []Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - []Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - []Соотнесите выводы с продажами игр на других платформах.
# - []Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# ### Шаг 4. Составьте портрет пользователя каждого региона
# - []Определите для пользователя каждого региона (NA, EU, JP):
#   - []Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#   - []Самые популярные жанры (топ-5). Поясните разницу.
#   - []Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# ### Шаг 5. Проверьте гипотезы
# - []Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - []Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
# - []Поясните:
#   - []Как вы сформулировали нулевую и альтернативную гипотезы;
#   - []Какой критерий применили для проверки гипотез и почему.
#
# ### Шаг 6. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# ### Описание данных
# - `Name` — название игры
# - `Platform` — платформа
# - `Year_of_Release` — год выпуска
# - `Genre` — жанр игры
# - `NA_sales` — продажи в Северной Америке (миллионы проданных копий)
# - `EU_sales` — продажи в Европе (миллионы проданных копий)
# - `JP_sales` — продажи в Японии (миллионы проданных копий)
# - `Other_sales` — продажи в других странах (миллионы проданных копий)
# - `Critic_Score` — оценка критиков (максимум 100)
# - `User_Score` — оценка пользователей (максимум 10)
# - `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
# - Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Выполнение

# %% [markdown]
# ### Шаг 1. Откроем файл с данными и изучим общую информацию <a id='2'></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats as st

# %%
try:
    data = pd.read_csv(
        '/Users/macbookair/Yandex.Disk.localized/01_Data_analyst/GitHub/DA_yandex_project_datasets/05_sborn_01_games.csv'
    )
except:
    data = pd.read_csv('/datasets/games.csv')
display('Общий вид дата фрейма', data.head(5))
# Out:
# 'Общий вид дата фрейма'
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> в сетевой версии данные не загружены

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Вообще ничего не понял, прошу подробнее!

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />У нас два пути для загрузки файла, первый локальный — для тебя
#
#         data = pd.read_csv('/Users/macbookair/Yandex.Disk.localized/Проекты_юпитер/games.csv')
#
# второй для твоих коллег, чтобы у них данные подкачались, локальный путь не сработает
#
#         data = pd.read_csv('/datasets/games.csv')
#
# а управляет всем этим конструкция Try - Except, если первый путь не сработает, то загрузится датасет с сетевой папки

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Для подгрузки данных стоит использовать конструкцию try-except, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей
#
# [Try - Except](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)

# %%
display('Информация по численным данным', data.describe())
# Out:
# 'Информация по численным данным'
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
display('Информация по данным', data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# 'Информация по данным'
# None

# %%
display('Информация по пропущенным значениям', data.isna().sum())
# Out:
# 'Информация по пропущенным значениям'
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# Посчитаем и выведем на экран какой % ДФ по колонкам имеет пропуски в значениях. <a id='nan_count'></a>

# %%
# создадим ДФ data_nan , в котором отсортируем по убыванию сумму строк с пропусками 
data_nan = pd.DataFrame(data=data.isna().sum().sort_values(ascending=False), 
                        columns=['count_nan']).reset_index(drop=False)
# Добавим колонку с указанием какая это часть от всего ДФ
data_nan['percent'] = data_nan['count_nan'] / data.shape[0] * 100
data_nan
# Out:
#               index  count_nan    percent
# 0      Critic_Score       8578  51.319174
# 1            Rating       6766  40.478612
# 2        User_Score       6701  40.089740
# 3   Year_of_Release        269   1.609333
# 4              Name          2   0.011965
# 5             Genre          2   0.011965
# 6          Platform          0   0.000000
# 7          NA_sales          0   0.000000
# 8          EU_sales          0   0.000000
# 9          JP_sales          0   0.000000
# 10      Other_sales          0   0.000000

# %%
data_nan.plot(y='percent', x='index', kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %%
rt = (data.isna().mean()*100)\
.to_frame().rename(columns = {0:'space'})\
.query('space > 0').sort_values(by = 'space', ascending = True)
rt
# Out:
#                      space
# Name              0.011965
# Genre             0.011965
# Year_of_Release   1.609333
# User_Score       40.089740
# Rating           40.478612
# Critic_Score     51.319174

# %% [markdown]
# Если Year_of_Release пропущено 1,6% и мы можем просто избавиться от этих пропусков, то пропуски в `Critic_Score, Rating, User_Score` пропуски более 40% и нам нужно будет решать как заменить пропуски.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Принял

# %%
data.hist(bins=20, figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#         array([[<AxesSubplot:title={'center':'Year_of_Release'}>,
#                 <AxesSubplot:title={'center':'NA_sales'}>],
#                [<AxesSubplot:title={'center':'EU_sales'}>,
#                 <AxesSubplot:title={'center':'JP_sales'}>],
#                [<AxesSubplot:title={'center':'Other_sales'}>,
#                 <AxesSubplot:title={'center':'Critic_Score'}>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Супер, эти строчки меня всегда бесили))

# %% [markdown]
# - Данные имеют разный регистр. Необходимо будет привести к единому (строчные буквы)
# - Некоторые данные имеют значения дробного формата, например `Year_of_Release`
# - `User_Score` не может иметь формат `object`
# - В колонке `rating` пока что не понятны обозначения.
# - Есть пропуски в данных. Пропущен год релиза по части данных, а также оценки и рейтинг. Если Year_of_Release пропущено 1,6% и мы можем просто избавиться от этих пропусков, то пропуски в `Critic_Score, Rating, User_Score` пропуски более 40% и нам нужно будет решать как заменить пропуски.
# - По гистограмме данны равномерны, выбросов не видно. В 2007м - 2010м году больше всего было релизов.

# %% [markdown]
# Отдельно по графе `Rating`

# %%
data['Rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Нашел данные из интернета по поводу рейтинга `ESRB` [Википедия](https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board)

# %%
esrb = pd.DataFrame({
    'rating':['E', 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'],
    'description':['ereryone', 
                   'mature', 
                   'teen', 
                   'Everyone_10_and_older', 
                   'ereryone', 
                   'Adults_Only_18+', 
                   'Early_childhood', 
                   'Rating Pending',],
    'eranslate':['для_всех', 
                 'для_взрослых', 
                 'для_детей', 
                 'от_10_лет_и_старше', 
                 'для_всех', 'для_взрослых', 
                 'для_детей_младшего_возраста', 
                 'рейтинг_ожидается',]
})
esrb
# Out:
#   rating            description                    eranslate
# 0      E               ereryone                     для_всех
# 1      M                 mature                 для_взрослых
# 2      T                   teen                    для_детей
# 3   E10+  Everyone_10_and_older           от_10_лет_и_старше
# 4    K-A               ereryone                     для_всех
# 5     AO        Adults_Only_18+                 для_взрослых
# 6     EC        Early_childhood  для_детей_младшего_возраста
# 7     RP         Rating Pending            рейтинг_ожидается

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ### Шаг 2. Подготовка данных <a id='3'></a>

# %%
data.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.columns = [x.lower() for x in data.columns] # Преобразуем столбцы к нижнему регистру

# %%
for i in ['name', 'platform', 'genre']: # Преобразуем значения ДФ к нижнему регистру. Колонку Rating пока что отсавлю.
    data[i] = data[i].str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> классное решение привести к нижнему регистру категориальные данные, это позволит найти часть неявных дубликатов

# %% [markdown]
# Займемся типами данных:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Посмотрим что из себя представляют значения в `critic_score, user_score`

# %%
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %%
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# Необходимо преобразовать тип в колонках:
# - year_of_release (Год не может быть дробным числом)
# - critic_score (тип данных в дф - float, хотя значения бвсе целые) - Преобразовать в int
# - user_score (тип данных в дф object, хотя значения дробные) Есть доп. значение `tbt` - преобразуем колонку в `float`

# %% [markdown]
# ---

# %% [markdown]
# - `year_of_release` и `critic_score` заменим формат на `int` через цикл, исключая нулевые значения

# %%
#repl_int = ['year_of_release', 'critic_score']

#for i in repl_int:
#    data[i] = round(data[data[i].notnull()][i].astype(int))

# %% [markdown]
# Метод выше не дает заменить значения на int. Но удалять строки с отсутствующим годом релиза не стоит, так как статистика по жанру нам понадобится. Заменим пропуски на 0. А лучше на 1900 чтобы на гистограммах небыло большой пропасти в дальнейшем:

# %%
data['year_of_release'] = data['year_of_release'].fillna(1900)
data['year_of_release'] = data['year_of_release'].astype(int)

# %% [markdown]
# `critic_score` оставляем без изменений. Потому как заполнить отсутствующие значения нам нечем. И удалить половину ДФ мы не можем. Тип данных float, работать с данными сможем. Что не сказать про `user_score`

# %% [markdown]
# `user_score` - ситуация подобная, выдумать значения мы не можем. Заменить средним тоже не можем. Работаем с тем что есть. Только вот проблема - тип данных `object` Заменить на `float` нам не даст значение `tbd` . В интернете нашел определние на сайте [bf.ru](https://fb.ru/article/171345/tbd---chto-znachit-eto-sokraschenie) означает:
# - To Be Determined, то есть "Будет определено". Очень часто подобное сокращение можно встретить в анонсах компьютерных игр. Когда разработчик той или иной игры уже сообщил о том, что она готовится к выходу, но пока еще не может назвать точные данные
#
# По аналогии будем считать, что `TBD` значит что данных попросту еще нет или еще не определены. Выдумать мы их не можем. поэтому заменим `tbd` на пустые значения.

# %%
data.loc[data['user_score'] == 'tbd', 'user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
# посчитаем сколько теперь пропусков в `user_score` 
data['user_score'].isna().sum() / data.shape[0] * 100
# Out:
# 54.59168411606342

# %% [markdown]
# Стало 54%, а было [считали выше](#nan_count) 40%.Все изза значения `tbd` Зато теперь можем поменять данные на `float`

# %%
# Присваиваем тип данных float
data['user_score'] = data['user_score'].astype(float)

# %% [markdown]
# Еще у нас есть по 2 пропуска в значениях `name` и `rating`. Проверим, это два значения или 4? Выведем на экран.

# %%
print(data.shape)
data[data['name'].isna()]
# Out:
# (16715, 11)
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      gen             1993   NaN      1.78      0.53      0.00
# 14244  NaN      gen             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %% [markdown]
# Получили пропуск в name соответствует пропуску в genre. Первая строка это конечно почти 2 млн проданных копий. Но думаю эти значения будут бесполезны для нас, поскольку отсутствует значения рейтинга и оценок. Принимаю решение просто удалить две строки.

# %%
data = data.drop(labels=[659, 14244], axis=0, errors='ignore') # Удаляем
data['name'].isna().sum() # Проверяем
# Out:
# 0

# %% [markdown]
# ##### Причины пропусков:
# - Часть значений просто не была посчитана - `tbd`
# - Человеческий фактор при выгрузке данных или сведении таблиц
# - Дополнение к предыдущему - техническая ошибка в том числе при сведении с разных платформ.
# - Дополнение к предыдущему - на разных платформах оценка может отличаться (похоже на логичную причину отсутствия рейтинга)

# %% [markdown]
# ---

# %% [markdown]
# #### Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец

# %%
data['sum_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Голову ломал на этом этапе, сопротивлялся делать через "+" )) БлагоДарю за подсказку!

# %%
data.head(5) # Проверяем
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1      3.58      6.81         0.77           NaN         NaN    NaN      40.24
# 2     12.76      3.79         3.29          82.0         8.3      E      35.52
# 3     10.93      3.28         2.95          80.0         8.0      E      32.77
# 4      8.89     10.22         1.00           NaN         NaN    NaN      31.38

# %% [markdown]
# ##### Чек-лист
# - [x]Замените названия столбцов (приведите к нижнему регистру);
# - [x]Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
#   - [x]Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#   - [х]Опишите причины, которые могли привести к пропускам;
#   - [x]Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# - [х]Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
#  11  sum_sales        16713 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# ---

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных <a id='4'></a>

# %% [markdown]
# - Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
data.groupby('year_of_release')['name'].count().plot(kind='bar', figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
fig, ax = plt.subplots(figsize=(10,3))

data.groupby('year_of_release')['name'].count().plot(ax=ax, kind='bar')
ax.set_ylabel('кол-во')
ax.set_xlabel('год релиза')
# Out:
# Text(0.5, 0, 'год релиза')

# %% [markdown]
#     - с 1991 года заметен рост. Пик приходится на 2007, 2008 года. За эти 2 года выпущено 2800 релизов. После 2011г заметно количество релизов сократилось в двое.
#     --------------------------------------------------------------------------------------------------
#     - Для решения нашей задачи, нам точно не важны данные с 1980 по 1991год.
#     - с 1993 по 2007 Мы здесь можем проанализировать сильное развитие игровой индустрии, а затем спад после 2009года.
#     - Для решения задачи нам более важен период 2012 - 2016г

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, наглядный
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Принял

# %% [markdown]
# ---

# %% [markdown]
# - Посмотрим, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#   - Для начала посмотрим в целомплатформы лидеры по релизам и по сумме заработанной выручки с продажи

# %%
data.groupby('platform').agg({'name':'count'}).sort_values(
    'name', ascending=False).plot(kind='bar', figsize=(10,3), title='Кол-во релизов за весь период')
# Out:
# <AxesSubplot:title={'center':'Кол-во релизов за весь период'}, xlabel='platform'>

# %% [markdown]
# Самый трудолюбивые платформы которыесделали больше всего релизов: **ps2, ds** за ними идут **ps3, wii, x360, psp** По крайней мере, для меня не известна только ds. Остальные очень сильно в свое время гремели в рекламе.

# %%
data.groupby('platform').agg({'sum_sales':'sum'}).sort_values(
    'sum_sales', ascending=False).plot(kind='bar', figsize=(10,3), title='Объем продаж по платформам')
# Out:
# <AxesSubplot:title={'center':'Объем продаж по платформам'}, xlabel='platform'>

# %% [markdown]
# Несомненный лидер по колчеству выпущенных игр и по объему продаж - **PS2**. Оно и логично, самая известная платформа, к тому же лидер по релизам. За ним идут **x360, ps3, wii, ds** В общем кто хорошу трудится, тот хорошо и зарабатывает.

# %% [markdown]
# это все очевидно, но выше мы рассмотрели данные за весь период. Мы прекрасно понимаем что какието платформы повляются в момент исчезания старой.
# - Построим график того, как менялись продажи по всем платформам с годами.

# %%
for i in data['platform'].unique():
    data[(data['platform'] == i) &
     (data['year_of_release'] != 1900)].groupby('year_of_release')['sum_sales'].sum().plot(figsize=(10,4)).legend(i)

# %% [markdown]
# Не понимаю зачем я это составил, не зная как сделать нормально=) Не выяснил как посмотреть легенду чтобы оценить продолжительность в годах начала релизов платформы и конец.

# %% [markdown]
# Вероятно можно было сделать проще - прошу подсказать) Как Я решил задачу:

# %%
platform_list = [] # Создаю пуслой список для названий платформ
platform_duration_yers = [] # Создаю пуслой список для вычисления кол-ва лет

# Создадим цикл, и методом append добавляем постепенно разницу max() and min()
for i in data['platform'].unique():
    
    platform_list.append(i)
    
    platform_duration_yers.append(
        data[(data['platform'] == i) & (data['year_of_release'] != 1900)]['year_of_release'].max()\
        - data[(data['platform'] == i) & (data['year_of_release'] != 1900)]['year_of_release'].min()
    )

# Создаем датафрейм и сразу гистограмму    
pd.DataFrame({'platform':platform_list, 'years':platform_duration_yers})\
    .sort_values('years', ascending=False).reset_index(drop=True)\
    .plot(x='platform', kind='bar', figsize=(10,4));

# %% [markdown]
# Игры на **pc** выпускаются более 30 лет. Популярные **x360, ps2, psp, wii** около 10 лет.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         От использования циклов стоит избавляться (при переборе строк в датасете), они затратные по вычислительным ресурсам

# %% [markdown]
# ### check gap

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию (может повлиять на расчет среднего срока актуальности платформ)
#
# При расчете характерного срока стоит учесть аномалию (DS — выброс 1985 года), отклонение (PC — слишком долго на рынке и не игровая приставка) и новые платформы (срок продаж не завершен)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Поправку принял. Я мало играл в компьютерные игры и приставки, может поэтому не смутило по DS аномалию 1985
#
#     - По этому выбросу прям странно сейчас. [https://disk.yandex.ru/i/AoxDybBjvAe95w](скрин) Почему-то при построениее через. pivot_table, аномалии не показало.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> (PC — слишком долго на рынке и не игровая приставка) - Не приставка. Платформа под которую выпускаются игры. и новые платформы (срок продаж не завершен). Не понял, что ты хочешь этим сказать мне!

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Срок жизни у РС он иного характера чем у PS3, у РС нет даты начала и даты конца, она постоянно модернизируется ..., точнее он

# %% [markdown]
# Уберем аномалию на платформе ds

# %%
data.query('platform == "ds"')\
    .query('year_of_release > 1900')\
    .sort_values('year_of_release', ascending=True).head(5)
# Out:
#                                                  name platform  \
# 15957             strongest tokyo university shogi ds       ds
# 13463                               cocoto kart racer       ds
# 11517                           kenshuui tendo dokuta       ds
# 4421   the urbz: sims in the city (all regions sales)       ds
# 7902                          daigasso! band brothers       ds
#
#        year_of_release       genre  na_sales  eu_sales  jp_sales  other_sales  \
# 15957             1985      action      0.00      0.00      0.02          0.0
# 13463             2004      racing      0.04      0.00      0.00          0.0
# 11517             2004  simulation      0.00      0.00      0.08          0.0
# 4421              2004  simulation      0.40      0.01      0.02          0.0
# 7902              2004        misc      0.00      0.00      0.19          0.0
#
#        critic_score  user_score rating  sum_sales
# 15957           NaN         NaN    NaN       0.02
# ...

# %% [markdown]
# Удалим 15957 строку:

# %%
data = data.drop(labels=[15957], axis=0, errors='ignore').reset_index(drop=True)

# %%
### жизненный срок платформы, не учитывает аномалию DS

years_of_life = (
                    data.query('year_of_release > 1900')
                    .pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
                )
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life.sort_values(by='years_of_life', ascending=False).head(10)
# Out:
#            min   max  years_of_life
# platform
# pc        1985  2016             31
# gb        1988  2001             13
# nes       1983  1994             11
# x360      2005  2016             11
# psp       2004  2015             11
# ps2       2000  2011             11
# dc        1998  2008             10
# wii       2006  2016             10
# ps3       2006  2016             10
# 2600      1980  1989              9

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Содержит выбросы
#
#         years_of_life

# %%
years_of_life
# Out:
#            min   max  years_of_life
# platform
# 2600      1980  1989              9
# 3do       1994  1995              1
# 3ds       2011  2016              5
# dc        1998  2008             10
# ds        2004  2013              9
# gb        1988  2001             13
# gba       2000  2007              7
# gc        2001  2007              6
# gen       1990  1994              4
# gg        1992  1992              0
# n64       1996  2002              6
# nes       1983  1994             11
# ng        1993  1996              3
# pc        1985  2016             31
# pcfx      1996  1996              0
# ps        1994  2003              9
# ps2       2000  2011             11
# ps3       2006  2016             10
# ps4       2013  2016              3
# psp       2004  2015             11
# psv       2011  2016              5
# sat       1994  1999              5
# scd       1993  1994              1
# snes      1990  1999              9
# tg16      1995  1995              0
# ...

# %%
data.query('platform == "pc"')\
    .query('year_of_release > 1900')\
    .sort_values('year_of_release', ascending=True).head(5)
# Out:
#                 name platform  year_of_release       genre  na_sales  \
# 14468      alter ego       pc             1985  simulation      0.00
# 14619        simcity       pc             1988  simulation      0.00
# 768     simcity 2000       pc             1992  simulation      1.20
# 2611   the 7th guest       pc             1992   adventure      0.02
# 12649      syndicate       pc             1992    strategy      0.00
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 14468      0.03       0.0         0.01          59.0         5.8      T
# 14619      0.02       0.0         0.01          64.0         2.2   E10+
# 768        0.84       0.0         0.10           NaN         NaN    NaN
# 2611       0.77       0.0         0.00           NaN         NaN      T
# 12649      0.05       0.0         0.01           NaN         NaN    NaN
#
#        sum_sales
# 14468       0.04
# 14619       0.03
# 768         2.14
# 2611        0.79
# 12649       0.06

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Супер, спасибо!

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Согласен, ПК слишком долго на рынке и влияет сильно на картину в целом. Это отклонение и я понимаю это.

# %%
years_of_life.boxplot(column='years_of_life')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Значение в 31 это выброс

# %%
years_of_life['years_of_life'].hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame({'platform':platform_list, 'years':platform_duration_yers})\
.sort_values('years', ascending=False).reset_index(drop=True).hist(bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'years'}>]], dtype=object)

# %% [markdown]
# Примено платформа является популярной 5 - 11 лет. Больше этого срока выдержит не любая платформа.

# %%
# ДОЛГИМИ ТРУДАМИ вывести графики и показать легенду на графике, методом проб и ошибок получилось:
data[data['year_of_release'] != 1900].pivot_table(
    index=['year_of_release'], 
    columns='platform', 
    values='sum_sales', 
    aggfunc='sum').plot.line(figsize=(10,9)
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# - Выберем не все, а ТОП 5 платформ по объему выручки за весь период. и построим графиг распределения по годам.

# %%
data.head(5)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1      3.58      6.81         0.77           NaN         NaN    NaN      40.24
# 2     12.76      3.79         3.29          82.0         8.3      E      35.52
# 3     10.93      3.28         2.95          80.0         8.0      E      32.77
# 4      8.89     10.22         1.00           NaN         NaN    NaN      31.38

# %%
# создадим ДФ rating_platform_sales с объемом продаж по платформам
rating_platform_sales = (
    data
    .groupby('platform')
    .agg({'sum_sales':'sum'})
    .sort_values(by='sum_sales', ascending=False)
    .reset_index(drop=False)
)

display(rating_platform_sales.head(7))
rating_platform_sales.plot(kind='bar', x='platform', figsize=(10,4))
# Out:
#   platform  sum_sales
# 0      ps2    1255.77
# 1     x360     971.42
# 2      ps3     939.65
# 3      wii     907.51
# 4       ds     806.10
# 5       ps     730.86
# 6      gba     317.85
# <AxesSubplot:xlabel='platform'>

# %% [markdown]
# Принял решение рассмотреть ТОП6, Поскольку 6я платформа это ps, и она имеет хороший объем продаж. После нее **gba** в два раза ниже ps

# %%
#rating_platform_sales.loc[:4, 'platform']

platform_top6 = list(rating_platform_sales['platform'].loc[:5])
platform_top6
# Out:
# ['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps']

# %%
for i in list(rating_platform_sales.loc[:5, 'platform']):
    data[(data['platform'] == i) & (data['year_of_release'] > 1900)]\
    .groupby('year_of_release')['sum_sales'].sum().plot(figsize=(10,4))

# %% [markdown]
# Теперь сделаем то-же самое через `pivot_table` и `plot.line()`

# %%
data.query('platform in @platform_top6').query('year_of_release != 1900')\
    .pivot_table(
    index='year_of_release',
    columns='platform',
    values='sum_sales',
    aggfunc=('sum')
).plot.line(figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# - Любые тренды имеют стремительный подъем и неминуемый спад
# - Отчетливо видно, примерно 10 лет популярна платформа

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# ---

# %%
data.groupby('year_of_release').agg({'name':'count'}).plot(kind='bar', figsize=(10,2), title='Кол-во релизов по годам')
# Out:
# <AxesSubplot:title={'center':'Кол-во релизов по годам'}, xlabel='year_of_release'>

# %% [markdown]
# - Возьмем данные за соответствующий актуальный период. Актуальный период необходимо определить. Основной фактор для определения — эти данные помогут построить прогноз на 2017 год.
#   - На мой взгял необходимо рассмотреть период в 4 года 2013 - 2016г. потому как:

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#
#
# __Далее на проекте стоит использовать датасет с актуальными данными, не ограничивая при этом перечень платформ из актуального периода__

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Именно так я и сделал. Не понимаю что переделывать. Все платформы и есть
#
# [https://disk.yandex.ru/i/xja-i3YfoWbeRw](#Все)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Основной смысл заключался в изменении периода для анализа
#
# В первой версии проекта был выбран период в 10 лет ... Это скрин с твоего проекта
#
# ![image.png](attachment:image.png)
#
# Если выбрать 4 года, мы также захватим уходящие платформы

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошо, на сколько я понял - 4 много. Выберу тогда 3 года. (чтобы точно попали 14, 15й год как полноценные. В 2016м могут быть не все данные)

# %% [markdown]
# Оставим актуальный период

# %%
data = data.query('year_of_release >= 2014')

# %%
data.pivot_table(
    index='year_of_release',
    columns='platform',
    values='sum_sales',
    aggfunc=('sum')
).plot.line(style = 'o-', figsize=(10,5));

# %% [markdown]
# - Стоит отметить нисходящий тренд по объему продаж. Рынок игор падает.
# - ТОП-3 платформа на конец 2016 года: **ps4, xone, pc, 3ds** Потенциально прибыльные платформы.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить перечень перспективных платформ
#
#
# 30-тилетняя история персональных компьютеров говорит, что игры для PC можно включить в рекомендацию

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Согласен. Примерно один и тотже цвет получился у ПК и Xone, поэтому не правильно описал.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит ограничивать перечень платформ из актуального периода для оценки прибыльности платформ__
#
# диаграмму размаха перерисовать на актуальной выборке с полным перечнем платформ

# %%
data.sort_values(by='sum_sales', ascending=False)\
.boxplot(
    column='sum_sales', 
    by='platform', 
    figsize=(15, 8)
).set_ylim(0, 5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает 100% масштаб? И какой график добавить?

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Такой же, но без ограничения по оси у (.set_ylim(0, 5))
#
#         data.query('year_of_release != 1900').query('year_of_release >= 2013').sort_values(by='sum_sales', ascending=False)\
#         .boxplot(
#             column='sum_sales',
#             by='platform',
#             figsize=(15, 8)
#         ).set_ylim(0, 5)

# %% [markdown]
# Посмотрим диаграммы размаха вцелом: 100% масштаб.

# %%
data.sort_values(by='sum_sales', ascending=False)\
.boxplot(
    column='sum_sales', 
    by='platform', 
    figsize=(15, 8)
);

# %% [markdown]
# PS4 Бьет рекорды!

# %%
rating_platform_sales = (
    data
    .groupby('platform')
    .agg({'sum_sales':'sum'})
    .sort_values(by='sum_sales', ascending=False)
    .reset_index(drop=False)
)

rating_platform_sales.plot(kind='bar', x='platform', figsize=(10,4));

# %% [markdown]
# ---

# %% [markdown]
# #### Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
# - Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.
# - Сформулируем выводы.

# %% [markdown]
# Еще раз посмотрим и выделим самую популярною площадку.

# %%
data.groupby('platform').agg({'sum_sales':'sum'})\
.sort_values('sum_sales', ascending=False).plot(kind='bar', figsize=(7,2), title='продажи');

data.groupby('platform').agg({'name':'count'})\
.sort_values('name', ascending=False).plot(kind='bar', figsize=(7,2), title='кол-во релизов');

# %% [markdown]
# И по количеству релизов и по объему продаж можем сказать что самая популярная плафтформа : **ps4**

# %%
# проверка "без notna()"
score = ['critic_score', 'user_score']
for i in score:
    print('Значение корреляции для', i, '=', data[data['platform'] == 'ps4'][i]\
          .corr(data[data['platform'] == 'ps4']['sum_sales']))
# Out:
# Значение корреляции для critic_score = 0.40266141068104083
# Значение корреляции для user_score = -0.040131589472697356

# %%
# напишу цикл для вывода 
score = ['critic_score', 'user_score']

for i in score:
    print('Значение корреляции для', i, '=', data[(data['platform'] == 'ps4') & (data[i].notna())][i]\
          .corr(data[(data['platform'] == 'ps4') & (data['sum_sales'].notna())]['sum_sales']))
    
    # строим scatter
    data.plot.scatter(
                                                            x='sum_sales', 
                                                            y=i, 
                                                            figsize=(10,4), 
                                                            alpha=0.5, 
                                                            title=i
                                                            )
# Out:
# Значение корреляции для critic_score = 0.40266141068104083
# Значение корреляции для user_score = -0.040131589472697356

# %% [markdown]
#     - Все логично, для оценок критиков чем выше оценка, тем выше средняя по продажам. Чем качественнее игра, тем лучше оценка, тем больше продаж. Покупатель доверяет оценке критиков.
#     - Оценка пользователей никак не коррелирует с продажами.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#        Все логично, чем выше оценка, тем выше средняя по продажам
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Определенно зависимость есть в том, что игры которые собрали большой объем продаж, практически не получают низких оценок. То есть:
#
# - Успешная по продажа игра - она же и популярная по отзывам - они высокие
# - Но также есть высокие отзывы у игр с маленьким объемом продаж.
#
#
# вывод: Есть определенные причины (в не рамок нашего проекта) которые заставляют игру с высоким рейтингом стать еще успешнее и собрать большие продажи. Например это грамотны маркетинг. И нету ниодного случая чтобы игра с низким рейтингом собрала большой объем продаж.

# %% [markdown]
# Соотнесите выводы с продажами игр на других платформах ТОП6. Для этого выведем корреляцию.

# %%
platform_top6 = data.groupby('platform')\
    .agg({'sum_sales':'sum'})\
    .sort_values('sum_sales', ascending=False)\
    .reset_index(drop=False)['platform'].loc[:5].tolist()

# %%
platform_top6
# Out:
# ['ps4', 'xone', '3ds', 'ps3', 'x360', 'wiiu']

# %%
user_corr = []
critic_corr = []
sum_sales_corr = []

for i in platform_top6:
    user_corr.append(round(data.query('platform == @i')['user_score']\
                     .corr(data.query('platform == @i')['sum_sales']), 3))
    
    critic_corr.append(round(data.query('platform == @i')['critic_score']\
                       .corr(data.query('platform == @i')['sum_sales']), 3))
    
corr_data = pd.DataFrame({
    'platform':platform_top6,
    'user_corr':user_corr,
    'critic_corr':critic_corr,
}
).set_index('platform')

corr_data
# Out:
#           user_corr  critic_corr
# platform
# ps4          -0.040        0.403
# xone         -0.070        0.429
# 3ds           0.215        0.314
# ps3          -0.167        0.447
# x360         -0.138        0.526
# wiiu          0.408        0.370

# %%
import seaborn

# %%
plt.figure(figsize=(5,3))
seaborn.heatmap(corr_data, cmap="Greens", vmax=1, annot=True)
# Out:
# <AxesSubplot:ylabel='platform'>

# %% [markdown]
#     - Показатели корреляции по оценкам критиков практически такие же и по другим играм
#     - Оценка пользователей редко влияет и имеет положительную корреляцию. Положительная корр. только по некоторым платформам.

# %%
data.query('platform == @platform_top6[0]').head(3)
# Out:
#                          name platform  year_of_release    genre  na_sales  \
# 31  call of duty: black ops 3      ps4             2015  shooter      6.03
# 42         grand theft auto v      ps4             2014   action      3.96
# 77                    fifa 16      ps4             2015   sports      1.12
#
#     eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 31      5.86      0.36         2.38           NaN         NaN    NaN
# 42      6.31      0.38         1.97          97.0         8.3      M
# 77      6.12      0.06         1.28          82.0         4.3      E
#
#     sum_sales
# 31      14.63
# 42      12.62
# 77       8.58

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сравнение показателей на нескольких платформах, позволяет набрать вес твоему исследованию, молодец
#
# Стоит добавить и диаграммы рассеяния для других платформ

# %% [markdown]
# ---

# %% [markdown]
# #### Посмотрим на общее распределение игр по жанрам. :
# - Что можно сказать о самых прибыльных жанрах?
# - Выделяются ли жанры с высокими и низкими продажами?

# %%
data.groupby('genre')\
    .agg({'sum_sales':'sum'})\
    .sort_values(by='sum_sales', ascending=False)\
    .reset_index(drop=False)
# Out:
#            genre  sum_sales
# 0         action     199.36
# 1        shooter     170.94
# 2         sports     109.48
# 3   role-playing     101.44
# 4           misc      37.55
# 5       fighting      28.22
# 6         racing      27.52
# 7       platform      18.09
# 8      adventure      17.55
# 9     simulation      13.13
# 10      strategy       3.96
# 11        puzzle       2.21

# %%
data.groupby('genre').agg({'sum_sales': 'sum'})\
    .sort_values('sum_sales', ascending=False).plot(kind='bar', figsize=(10,2), title='Объем продаж')
data.groupby('genre').agg({'name': 'count'})\
    .sort_values('name', ascending=False).plot(kind='bar', figsize=(10,2), title='Объем релизов')
# Out:
# <AxesSubplot:title={'center':'Объем релизов'}, xlabel='genre'>

# %%
data.query('genre == "action"').hist(figsize=(10,10));

# %% [markdown]
#     - Самый прибыльный жанр - action. Самый массовый жанр
#     - Низкую прибыль несет жанр стратегий.
#     - По самым прибыльным жанрам можно сказать что есть прямая корреляция от объема релизов.

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %%
data['genre'].unique()
# Out:
# array(['shooter', 'action', 'role-playing', 'sports', 'fighting',
#        'racing', 'misc', 'platform', 'simulation', 'adventure', 'puzzle',
#        'strategy'], dtype=object)

# %%
data.boxplot(
    column='sum_sales', 
    by='genre', 
    figsize=(12, 5)
).set_ylim(0, 4)

data.boxplot(
    column='sum_sales', 
    by='genre', 
    figsize=(12, 5)
).set_ylim(0, 1.7)
# Out:
# (0.0, 1.7)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Предположу: (потому как не допонимаю)
#
#
# - Самы НЕ стабильный жанр - платформаеры. Самый большой размах в продажах от одной к другой игре.
# - Самые стабильные это Adventure, Pazzle, Strategy. Достаточно логично, хоть они и не собирают рекордные продажи и прибыль, но они имеют своих ценителей и свою аудиторию.
# - А вот остальные жанры зависят от новой игры, будет ли она супер известная и крутая или нет.
#
#
# Риант, подскажи, это все что я смог сформулировать. Что можно сказать сравнительно про их медианы? Что можно сказать о прибыльности глядя на медиану?

# %%
# check
data.query('year_of_release > 2013')\
.boxplot(
    column='sum_sales', 
    by='genre', 
    figsize=(12, 5)
)
plt.suptitle(''); #  убирает служебный заголовок

data.query('year_of_release > 2013')\
.boxplot(
    column='sum_sales', 
    by='genre', 
    figsize=(12, 5)
).set_ylim(0, 1.7)
plt.suptitle(''); #  убирает служебный заголовок

# %% [markdown]
# - action и shooter потенциально рекорсмены по возможностям сделать рекордные продажи. Выбросы выше всех.
# - Самые стабильные это Adventure, Pazzle, Strategy. Достаточно логично, хоть они и не собирают рекордные продажи и прибыль, но они имеют своих ценителей и свою аудиторию.

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Самое важное__ — при отрисовке графиков и исследовании на проекте после определения актуального периода, мы используем только актуальные данные
#
# С изменением периода для анализа у нас кардинально меняется вывод

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Вроде я услышал и ограничил период на актуальный

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Две диаграммы и многое становиться ясным, какой из жанров наиболее успешен, а у какого выбросы составляют большую часть продаж, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе, чтобы уточнить в каком кол-ве продаются игры на платформе, какая из них более стабильна в продажах...
#
# Две хорошие статьи про диаграмму размаха
#
# [Визуализация категориальных данных](https://pyprog.pro/sns/sns_7_categorical_data.html?)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %% [markdown]
# ##### Чек-лист
# - [x] Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - [x] Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - [x] Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - [x] Не учитывайте в работе данные за предыдущие годы.
# - [x] Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - [x] Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - [x] Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - [x] Соотнесите выводы с продажами игр на других платформах.
# - [x] Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
pd.DataFrame(data.groupby('genre')['na_sales']\
                .sum()\
                .sort_values(ascending=False))\
                .reset_index(drop=False).loc[:4]['genre'].tolist()
# Out:
# ['shooter', 'action', 'sports', 'role-playing', 'misc']

# %%
pd.DataFrame({
    'top':['top_1', 'top_2', 'top_3', 'top_4', 'top_5'],
    'na_sales':[np.nan,np.nan,np.nan,np.nan,np.nan], 
    'eu_sales':[np.nan,np.nan,np.nan,np.nan,np.nan], 
    'jp_sales':[np.nan,np.nan,np.nan,np.nan,np.nan]
}).set_index('top')
# Out:
#        na_sales  eu_sales  jp_sales
# top
# top_1       NaN       NaN       NaN
# top_2       NaN       NaN       NaN
# top_3       NaN       NaN       NaN
# top_4       NaN       NaN       NaN
# top_5       NaN       NaN       NaN

# %% [markdown]
# ### Шаг 4. Составим портрет пользователя каждого региона <a id='5'></a>

# %% [markdown]
# - [] Определите для пользователя каждого региона (NA, EU, JP):
#     - [] Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#     - [] Самые популярные жанры (топ-5). Поясните разницу.
#     - [] Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
data.head(3)
# Out:
#                                          name platform  year_of_release  \
# 31                  call of duty: black ops 3      ps4             2015
# 42                         grand theft auto v      ps4             2014
# 47  pokemon omega ruby/pokemon alpha sapphire      3ds             2014
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31       shooter      6.03      5.86      0.36         2.38           NaN
# 42        action      3.96      6.31      0.38         1.97          97.0
# 47  role-playing      4.35      3.49      3.10         0.74           NaN
#
#     user_score rating  sum_sales
# 31         NaN    NaN      14.63
# 42         8.3      M      12.62
# 47         NaN    NaN      11.68

# %% [markdown]
# #### ТОП-5 платформ по регионам

# %%
#regions = ['na_sales', 'eu_sales', 'jp_sales']

#for i in regions:
#    top_r = data.groupby('platform').agg({i:'sum'})\
#    .sort_values(i, ascending=False)\
#    .reset_index(drop=False).loc[:4]
#    
#    print(i,':', top_r['platform'].tolist())
#    top_r.plot(x='platform', kind='bar', figsize=(3,2), title=('ТОП5 платформ по региону'))
#    plt.show()

# %% [markdown]
#     - В америке и европе предпочитают x360  и ps2
#     - Япония же очень любит nintendo. x360 в японии не в топе.

# %% [markdown]
# #### ТОП-5 жанров по региону

# %%
#for i in regions:
#    top_g = data.groupby('genre').agg({i:'sum'})\
#    .sort_values(i, ascending=False)\
#    .reset_index(drop=False).loc[:4]
#    
#    print(top_g['genre'].tolist())
#    top_g.plot(x='genre', kind='bar', figsize=(3,2), title=('ТОП5 жанров по региону'))
#    plt.show()

# %% [markdown]
#     - В америке и европе предпочитают Экшн игры
#     - Япония - ролевые игры

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 1980 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne
#
# https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/?ysclid=l4q3l4q0p8940570437
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html?highlight=append#pandas.DataFrame.append

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Логично что период с 1980года сильно может сиказить портрет. С 1980го по 2016год, человек который играл в 1980 в игры, стал старше на 37 лет. И вообще он теперь в 2016м еще геймер)
#
# - Поколение помнялось. Тогда для более точно определения портрета, возьмем данные за 11 лет. с 2006 по 2016г.

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Дублирую комментарий
#
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#
#
# __Далее на проекте стоит использовать датасет с актуальными данными, не ограничивая при этом перечень платформ из актуального периода__

# %%
# other_platform = pd.DataFrame({
#     i:[data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[5:].sum()[0]],
#     'platform':'other'
# }).set_index('platform')

# df11 = data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[:5]

# display(other_platform)

# df11

# %%
# df11 = data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[:5]

# %%
# num = 0
# for i in regions:
    
#     data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[:5].\
#     plot(kind='bar', ax=axes[num], title=title_sal[i])
#     num += 1

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Код не работает, можешь рассказать, что мы собирались сделать
#
#         num = 0
#         for i in regions:
#
#             data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[:5].\
#             plot(kind='bar', ax=axes[num], title=title_sal[i])
#             num += 1

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Это все было тестово. Все что проверял отразил полноценно в код ниже: (Сейчас не удаляю чтобы была история о чем велась реч)

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']
title_sal = {'na_sales': 'North America', 'eu_sales': 'Europe', 'jp_sales': 'Japan'}

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))

num = 0
for i in regions:
    
    
    other_platform = pd.DataFrame({
        i:[data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[5:].sum()[0]],
        'platform':'other'
    }).set_index('platform')
    
    df_1 = data.groupby('platform').agg({i: 'sum'}).sort_values(by=i, ascending=False)[:5]
    
    df_1.append(other_platform).\
    plot(kind='bar', ax=axes[num], title=title_sal[i], rot=40)
    print(i, df_1.index)
    
    num += 1
# Out:
# na_sales Index(['ps4', 'xone', 'x360', '3ds', 'ps3'], dtype='object', name='platform')
# eu_sales Index(['ps4', 'xone', 'ps3', 'pc', '3ds'], dtype='object', name='platform')
# jp_sales Index(['3ds', 'ps4', 'psv', 'ps3', 'wiiu'], dtype='object', name='platform')

# %% [markdown]
# - В Америке популярны приставки xone и PS4. На третьем месте x360. PS3 завершают ТОП5
#
# - В Европе PS4 лидер. Xone почти на втором месте популярности. За ними ps3, pc, 3ds.
#
# - Япония же очень любит 3ds.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))

num = 0
for i in regions:
    
    
    other_platform = pd.DataFrame({
        i:[data.groupby('genre').agg({i: 'sum'}).sort_values(by=i, ascending=False)[5:].sum()[0]],
        'genre':'other'
    }).set_index('genre')
    
    df_1 = data.groupby('genre').agg({i: 'sum'}).sort_values(by=i, ascending=False)[:5]
    
    df_1.append(other_platform).\
    plot(kind='bar', ax=axes[num], title=title_sal[i], rot=40)
    print(i, df_1.index)
    
    num += 1
# Out:
# na_sales Index(['shooter', 'action', 'sports', 'role-playing', 'misc'], dtype='object', name='genre')
# eu_sales Index(['action', 'shooter', 'sports', 'role-playing', 'racing'], dtype='object', name='genre')
# jp_sales Index(['role-playing', 'action', 'fighting', 'misc', 'shooter'], dtype='object', name='genre')

# %% [markdown]
# - В америке предпочитают shooter и action. В европе почти также, только Экшн игры на 1м месте.
# - Япония - ролевые игры и с таким же успехом по популярности - role-playing.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Это было сложно для меня! Но вроде справился!

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит изменить период для анализа, в рекомендацию для маркетологов, ТОП-5, попали пять «мертвых» платформ на 2017 г.
#
#         В Америке популярны приставки X360 и PS2. На третьем месте Wii. PS3 и DS завершают ТОП5

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не сразу, но ошибку понял.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в отдельном регионе?

# %%
esrb
# Out:
#   rating            description                    eranslate
# 0      E               ereryone                     для_всех
# 1      M                 mature                 для_взрослых
# 2      T                   teen                    для_детей
# 3   E10+  Everyone_10_and_older           от_10_лет_и_старше
# 4    K-A               ereryone                     для_всех
# 5     AO        Adults_Only_18+                 для_взрослых
# 6     EC        Early_childhood  для_детей_младшего_возраста
# 7     RP         Rating Pending            рейтинг_ожидается

# %% [markdown]
# Выясняем, что значение рейтинга "Е" и "К-А" это одно и тоже, только "К-А" устаревшие данные. Обозначает ипервый и второй -  everyone- Для всех. Поэтому заменим устаревшее "К-А" на "E"

# %%
data['rating'] = data['rating'].str.replace('K-A', 'E')

# %%
data['rating'] = data['rating'].fillna('Неизвестен')

# %%
data['rating'].unique()
# Out:
# array(['Неизвестен', 'M', 'E', 'T', 'E10+'], dtype=object)

# %% [markdown]
# Теперь выведем гистограммы по рейтингу по регионам:

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,3))

num = 0
for i in regions:
    
    data.groupby('rating').agg({i:'sum'})\
    .sort_values(i, ascending=False)\
    .reset_index(drop=False)\
    .plot(x='rating', kind='bar', ax=axes[num], title=title_sal[i], rot=40)
    
    num += 1

# %%
#старая реализация без subplots()
#for i in regions:
#    data.groupby('rating').agg({i:'sum'})\
#    .sort_values(i, ascending=False)\
#    .reset_index(drop=False)\
#    .plot(x='rating', kind='bar', figsize=(4,2))
#    plt.show()

# %% [markdown]
# Большая доля игр, по которым отсутствует рейтинг. Но из того что есть можно сказать что:
# - рейтинг "для всех" самый популярный везде.
# - Не смотря на "не известные данные" в европе популянее игры для взрослых. Популярнее чем в америке и японии. Европейская раскрепощенность, что сказать)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Интересно в чем причина, что на рынке Японии продается так много игр без рейтинга ESRB

# %% [markdown]
# ### Шаг 5. Проверка гипотезы <a id='6'></a>

# %%
data['platform'].unique()
# Out:
# array(['ps4', '3ds', 'xone', 'wiiu', 'ps3', 'x360', 'pc', 'wii', 'psv',
#        'psp'], dtype=object)

# %% [markdown]
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#     - H0: cредний пользовательский рейтинг платформ Xbox One и PC одинаковый
#     - H1: cредний пользовательский рейтинг платформ Xbox One и PC различается

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
alpha = .05

xone = data[(data['platform'] == 'xone') & (data['user_score'] > 0)]['user_score']   #  & (data['user_score'] > 0)
pc = data[(data['platform'] == 'pc') & (data['user_score'] > 0)]['user_score']

results = st.ttest_ind(xone, pc)
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.10450507919348415
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br /> Сейчас вот опять не понятно и сложно

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В выборке data у нас данные за период с 1980 по 2016 гг., приставка xone вышла в 2013 году, а рс уже лет 30 продается.
#
# Если не учесть этот момент и не выровнять выборки, мы можем исказить выводы стат. теста.
#
# Стоит отфильтровать данные по году, оставить записи старше  > 2012 года
#
#     Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Но теперь то с актуальным периодом все ок должно быть.

# %% [markdown]
# - Средние пользовательские рейтинги жанров Action и Sports разные.
#     - H0: cредний пользовательский рейтинг жанров Action и Sports одинаковые
#     - H1: cредний пользовательский рейтинг жанров Action и Sports разные

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы сформулированы некорректно
#
#         Средние пользовательские рейтинги жанров Action и Sports разные.
#         H0: cредний пользовательский рейтинг жанров Action и Sports разные
#         H1: cредний пользовательский рейтинг жанров Action и Sports одинаковые

# %%
action = data[(data['genre'] == 'action') & (data['user_score'] > 0)]['user_score']
sports = data[(data['genre'] == 'sports') & (data['user_score'] > 0)]['user_score']

results = st.ttest_ind(action, sports)
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 2.8711147985105864e-19
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Проверка результатов развернута под некорректные формулировки Н0 и Н1
#
#         if (results.pvalue > alpha):
#             print("Отвергаем нулевую гипотезу")
#         else:
#             print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.10406951359049141

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b> Студент </b></font>
# <br />
# <font size="3", color = "black">
# <br />  0.10406951359049141 означает что данные схожие по значениям
#
# - Переделал.

# %% [markdown]
#     - В первом случае нулевая гипотека выдвинута о схожести, поэтому при p < 0.05 мы можем сделать вывод что данные раздичаются
#     - Во втором случае нулевая гпотеза выдвинута о схожести, поэтому при полученном p **<** 0.05 мы можем сделать вывод что данные схожи.А значит не отвергаем нулевую гипотезу.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         Во втором случае нулевая гпотеза выдвинута о схожести, поэтому при полученном p **<** 0.05 мы можем сделать вывод что данные схожи.А значит не отвергаем нулевую гипотезу.
#
#
# У нас результат стат теста противоположный
#
#         p-значение: 2.8711147985105864e-19
#         Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить
#
#
#         - Во втором случае нулевая гпотеза выдвинута о схожести, поэтому при полученном p > 0.05 мы можем сделать вывод что данные схожи.А значит не отвергаем нулевую гипотезу.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# ## 5. Вывод <a id='9'></a>

# %% [markdown]
# - Выявить факторы определяющие успешность игр и закономерности.
# - Выделить потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# ### Игровая индустрия приносит разработчикам все меньше и меньше. Но люди не перестают играть.
#
# - Успешность игры конечно определяет качество, которое влияет на отзывы.
#
# - рекомендации на 2017 год:
#     - Для рынка NA сфокусировать основной бюджет закупок:
#             - на плформы **'ps4', 'xone', 'x360', '3ds', 'ps3'**
#             - на жанры **'shooter', 'action', 'sports', 'role-playing', 'misc'**
#
#     - Для рынка EU сфокусировать основной бюджет закупок:
#             - на плформы **'ps4', 'xone', 'ps3', 'pc', '3ds'**
#             - на жанры **'action', 'shooter', 'sports', 'role-playing', 'racing' **
#
#     - Для рынка JP сфокусировать основной бюджет закупок:
#             - на плформы **'3ds','ps4','psv','ps3','wiiu' **
#             - на жанры ** 'role-playing', 'action', 'fighting', 'misc', 'shooter'**
#
# - Если магазин не будет закупать для игры в таком колличестве, чтобы угодить всем платформам и жанрам, а сфокусируется на конкретных ТОП 5, то сможет избежать зависания товара на складе.
#
# - Делать выводы исходя из возрастного рейтинга не стоит, потомц как отсутствует очень большая часть данных.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно поправить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Теперь все в порядке

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно поправить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках
#
# мы формируем рекомендацию не для производителя игр, а для интернет магазина, для продажи или наполнения ассортимента

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить название
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + самое важное — переопределить актуальный период
#  + 1985
#  + дополнить перечень перспективных платформ
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез подправить выборки, Н0 и Н1, плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
    labels_c=sales.platform
    colours = {'Wii':'C0', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'steelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'C14', '2600':'C15', 'PSP':'C16', 
               'XOne':'C17',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2011

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2015

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ
